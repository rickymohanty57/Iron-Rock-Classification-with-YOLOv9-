# %%
from roboflow import Roboflow
rf = Roboflow(api_key="6HwSgw3Vj0rxBQVrKzR8")
project = rf.workspace().project("comp-image")
model = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from IPython.display import display, Image
# visualize your prediction
model.predict("1.jpg", confidence=1, overlap=1).save("prediction1.jpg")
image_path = "prediction1.jpg"

# Display the image
display(Image(filename=image_path))

# %%
# visualize your prediction
model.predict("2.bmp", confidence=1, overlap=1).save("prediction2.jpg")
image_path = "prediction2.jpg"

# Display the image
display(Image(filename=image_path))

# %%
model.predict("2.2.bmp", confidence=1, overlap=1).save("prediction2.2.jpg")
image_path = "prediction2.2.jpg"

# Display the image
display(Image(filename=image_path))

# %%
model.predict("1.1.jpg", confidence=1, overlap=1).save("prediction1.1.jpg")
image_path = "prediction1.1.jpg"

# Display the image
display(Image(filename=image_path))

# %%
from IPython.display import display, Image
# visualize your prediction
model.predict("2.1.bmp", confidence=1, overlap=1).save("prediction2.1.jpg")
image_path = "prediction2.1.jpg"

# Display the image
display(Image(filename=image_path))
